# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')


! conda install -c rdkit rdkit -y
# Out:
# --2021-11-18 15:08:56--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   104MB/s    in 0.8s
#
# 2021-11-18 15:08:57 (104 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda install pytorch==1.8.0 torchvision==0.9.0 torchaudio==0.8.0 cudatoolkit=10.2 -c pytorch
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch==1.8.0
#     - torchaudio==0.8.0
#     - torchvision==0.9.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cffi-1.14.6                |   py37h400218f_0         223 KB
#     cudatoolkit-10.2.89        |       hfd86e86_1       365.1 MB
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     gmp-6.2.1                  |       h2531618_2         539 KB
#     gnutls-3.6.15              |       he1e5248_0         1.0 MB
#     jpeg-9b                    |       h024ee3a_2         214 KB
# ...

# %%
# !MMCV_WITH_OPS=1 FORCE_CUDA=1 pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu102/torch1.8.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu102/torch1.8.0/index.html
# ...
#      |████████████████████████████████| 45.8 MB 56 kB/s
# ...
#      |████████████████████████████████| 60.3 MB 28 kB/s
# ...
#      |████████████████████████████████| 596 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 185 kB 60.7 MB/s
# ...
#      |████████████████████████████████| 97 kB 7.0 MB/s
# ...

# %%
# !pip install mmdet
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 48.9 MB/s
# ...
#      |████████████████████████████████| 873 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.4 MB/s
# ...
#   Using cached Cython-0.29.24-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272834 sha256=a2bae037477c89df7bb9589a42152fa7d279eee141aac6452f10e2e416d84040
#   Stored in directory: /root/.cache/pip/wheels/bc/cf/1b/e95c99c5f9d1648be3f500ca55e7ce55f24818b0f48336adaf
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-py3-none-any.whl size=15354 sha256=20a31b7f119e85eda24216ccc52ff47f5e00f3200cd391a4d4e3af8512261752
#   Stored in directory: /root/.cache/pip/wheels/ba/ad/c8/2d98360791161cd3db6daf6b5e730f34021fc9367d5879f497
# Successfully built pycocotools terminaltables
# ...

# %%
# !pip install instaboostfast
# Out:
# ...
#      |████████████████████████████████| 38.2 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 29.2 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 21.3 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 58.7 MB/s
# ...
#      |████████████████████████████████| 178 kB 68.9 MB/s
# ...
#      |████████████████████████████████| 6.1 MB 39.3 MB/s
# ...
#   Created wheel for instaboostfast: filename=instaboostfast-0.1.2-py3-none-any.whl size=14787 sha256=43fde237d98e85bd9f49869a8e6ef9cd135bda6e9c0cd23eb25cbfaaf2426fb2
#   Stored in directory: /root/.cache/pip/wheels/f5/ff/88/1e808422f9e6b1f3c4356a2a3c54ff7f6a32595e7dba8cdf5f
# Successfully built instaboostfast
# ...

# %%
# !pip install git+https://github.com/cocodataset/panopticapi.git
# Out:
# ...
#   Cloning https://github.com/cocodataset/panopticapi.git to /tmp/pip-req-build-cpyub661
#   Running command git clone -q https://github.com/cocodataset/panopticapi.git /tmp/pip-req-build-cpyub661
# ...
#   Created wheel for panopticapi: filename=panopticapi-0.1-py3-none-any.whl size=8315 sha256=196525c252d32c013ca3fc1998382f6feb2f309711de0ff9013e27c64a36ee58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3mw6cwcq/wheels/ad/89/b8/b66cce9246af3d71d65d72c85ab993fd28e7578e1b0ed197f1
# Successfully built panopticapi
# ...

# %%
# !pip install git+https://github.com/lvis-dataset/lvis-api.git
# Out:
# ...
#   Cloning https://github.com/lvis-dataset/lvis-api.git to /tmp/pip-req-build-_6cprfwt
#   Running command git clone -q https://github.com/lvis-dataset/lvis-api.git /tmp/pip-req-build-_6cprfwt
# ...
#   Created wheel for lvis: filename=lvis-0.5.3-py3-none-any.whl size=14023 sha256=e3bf486b6a04e58608ed2b6d4a5d8a81ffad8e0765fc18d3ba7ab388632e1686
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1cbjk7la/wheels/6d/a7/b8/63ea37498ab3e27280c73ed521aa644e42a05bdcfab457f8fd
# Successfully built lvis
# ...

# %%
# !pip install albumentations>=0.3.2 --no-binary imgaug,albumentations

# %%
cd /content/drive/MyDrive/mmdetection-master
# Out:
# /content/drive/MyDrive/mmdetection-master

# %%
# !pip install ipykernel
# Out:
# ...
#      |████████████████████████████████| 125 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 102 kB 14.1 MB/s
# ...
#      |████████████████████████████████| 790 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 428 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 125 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 52.4 MB/s
# ...
#      |████████████████████████████████| 374 kB 63.8 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 60.7 MB/s
# ...
#      |████████████████████████████████| 59 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 68.9 MB/s
# ...
#      |████████████████████████████████| 86 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 53.1 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.5 MB/s
# ...

# %%
# !python tools/train.py my-config.py
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2021-11-18 15:33:54,642 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.7 (default, May  7 2020, 21:25:33) [GCC 7.3.0]
# CUDA available: True
# GPU 0: Tesla P100-PCIE-16GB
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.1.TC455_06.29190527_0
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.8.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v1.7.0 (Git Hash 7aed236906b1f7a05c0917e5257a1af05e9ff683)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.2
# ...

# %%
# !python tools/test.py /content/drive/MyDrive/mmdetection-master/my-config.py /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_16.pth --eval mAP
# Out:
# load checkpoint from local path: /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_16.pth
# [>>] 667/667, 5.3 task/s, elapsed: 126s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +-------+-----+------+--------+-------+
# | class | gts | dets | recall | ap    |
# +-------+-----+------+--------+-------+
# | 0     | 0   | 0    | 0.000  | 0.000 |
# | 1     | 0   | 0    | 0.000  | 0.000 |
# | 2     | 86  | 470  | 0.860  | 0.546 |
# | 3     | 20  | 110  | 0.850  | 0.687 |
# | 4     | 547 | 1971 | 0.909  | 0.675 |
# | 5     | 64  | 197  | 0.938  | 0.789 |
# | 6     | 0   | 0    | 0.000  | 0.000 |
# | 7     | 0   | 0    | 0.000  | 0.000 |
# | 8     | 0   | 0    | 0.000  | 0.000 |
# | 9     | 0   | 0    | 0.000  | 0.000 |
# | 10    | 0   | 0    | 0.000  | 0.000 |
# | 11    | 0   | 0    | 0.000  | 0.000 |
# | 12    | 0   | 0    | 0.000  | 0.000 |
# | 13    | 0   | 0    | 0.000  | 0.000 |
# | 14    | 0   | 0    | 0.000  | 0.000 |
# ...

# %%
# !python tools/test.py /content/drive/MyDrive/mmdetection-master/my-config.py /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_17.pth --eval mAP
# Out:
# load checkpoint from local path: /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_17.pth
# [>>] 667/667, 16.2 task/s, elapsed: 41s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +-------+-----+------+--------+-------+
# | class | gts | dets | recall | ap    |
# +-------+-----+------+--------+-------+
# | 0     | 0   | 0    | 0.000  | 0.000 |
# | 1     | 0   | 0    | 0.000  | 0.000 |
# | 2     | 86  | 442  | 0.849  | 0.542 |
# | 3     | 20  | 108  | 0.850  | 0.698 |
# | 4     | 547 | 1924 | 0.910  | 0.681 |
# | 5     | 64  | 198  | 0.938  | 0.789 |
# | 6     | 0   | 0    | 0.000  | 0.000 |
# | 7     | 0   | 0    | 0.000  | 0.000 |
# | 8     | 0   | 0    | 0.000  | 0.000 |
# | 9     | 0   | 0    | 0.000  | 0.000 |
# | 10    | 0   | 0    | 0.000  | 0.000 |
# | 11    | 0   | 0    | 0.000  | 0.000 |
# | 12    | 0   | 0    | 0.000  | 0.000 |
# | 13    | 0   | 0    | 0.000  | 0.000 |
# | 14    | 0   | 0    | 0.000  | 0.000 |
# ...

# %%
# !python tools/test.py /content/drive/MyDrive/mmdetection-master/my-config.py /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_18.pth --eval mAP
# Out:
# load checkpoint from local path: /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_18.pth
# [>>] 667/667, 16.3 task/s, elapsed: 41s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +-------+-----+------+--------+-------+
# | class | gts | dets | recall | ap    |
# +-------+-----+------+--------+-------+
# | 0     | 0   | 0    | 0.000  | 0.000 |
# | 1     | 0   | 0    | 0.000  | 0.000 |
# | 2     | 86  | 478  | 0.872  | 0.542 |
# | 3     | 20  | 110  | 0.850  | 0.675 |
# | 4     | 547 | 1934 | 0.907  | 0.677 |
# | 5     | 64  | 194  | 0.938  | 0.779 |
# | 6     | 0   | 0    | 0.000  | 0.000 |
# | 7     | 0   | 0    | 0.000  | 0.000 |
# | 8     | 0   | 0    | 0.000  | 0.000 |
# | 9     | 0   | 0    | 0.000  | 0.000 |
# | 10    | 0   | 0    | 0.000  | 0.000 |
# | 11    | 0   | 0    | 0.000  | 0.000 |
# | 12    | 0   | 0    | 0.000  | 0.000 |
# | 13    | 0   | 0    | 0.000  | 0.000 |
# | 14    | 0   | 0    | 0.000  | 0.000 |
# ...

# %%
# !python tools/test.py /content/drive/MyDrive/mmdetection-master/my-config.py /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_19.pth --eval mAP
# Out:
# load checkpoint from local path: /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_19.pth
# [>>] 667/667, 16.3 task/s, elapsed: 41s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +-------+-----+------+--------+-------+
# | class | gts | dets | recall | ap    |
# +-------+-----+------+--------+-------+
# | 0     | 0   | 0    | 0.000  | 0.000 |
# | 1     | 0   | 0    | 0.000  | 0.000 |
# | 2     | 86  | 469  | 0.860  | 0.544 |
# | 3     | 20  | 118  | 0.850  | 0.681 |
# | 4     | 547 | 1950 | 0.912  | 0.680 |
# | 5     | 64  | 198  | 0.938  | 0.780 |
# | 6     | 0   | 0    | 0.000  | 0.000 |
# | 7     | 0   | 0    | 0.000  | 0.000 |
# | 8     | 0   | 0    | 0.000  | 0.000 |
# | 9     | 0   | 0    | 0.000  | 0.000 |
# | 10    | 0   | 0    | 0.000  | 0.000 |
# | 11    | 0   | 0    | 0.000  | 0.000 |
# | 12    | 0   | 0    | 0.000  | 0.000 |
# | 13    | 0   | 0    | 0.000  | 0.000 |
# | 14    | 0   | 0    | 0.000  | 0.000 |
# ...

# %%
# !python tools/test.py /content/drive/MyDrive/mmdetection-master/my-config.py /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_20.pth --eval mAP
# Out:
# load checkpoint from local path: /content/drive/MyDrive/mmdetection-master/work_dirs/my-config/epoch_20.pth
# [>>] 667/667, 16.2 task/s, elapsed: 41s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +-------+-----+------+--------+-------+
# | class | gts | dets | recall | ap    |
# +-------+-----+------+--------+-------+
# | 0     | 0   | 0    | 0.000  | 0.000 |
# | 1     | 0   | 0    | 0.000  | 0.000 |
# | 2     | 86  | 439  | 0.860  | 0.557 |
# | 3     | 20  | 112  | 0.850  | 0.688 |
# | 4     | 547 | 1924 | 0.909  | 0.679 |
# | 5     | 64  | 196  | 0.938  | 0.784 |
# | 6     | 0   | 0    | 0.000  | 0.000 |
# | 7     | 0   | 0    | 0.000  | 0.000 |
# | 8     | 0   | 0    | 0.000  | 0.000 |
# | 9     | 0   | 0    | 0.000  | 0.000 |
# | 10    | 0   | 0    | 0.000  | 0.000 |
# | 11    | 0   | 0    | 0.000  | 0.000 |
# | 12    | 0   | 0    | 0.000  | 0.000 |
# | 13    | 0   | 0    | 0.000  | 0.000 |
# | 14    | 0   | 0    | 0.000  | 0.000 |
# ...
